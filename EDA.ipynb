# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=sns.load_dataset("iris")
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
v=LabelEncoder()
x=['sepal_length','petal_length','species']
for i in x:
    data[i]=v.fit_transform(data[i])
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0               8          3.5             4          0.2        0
# 1               6          3.0             4          0.2        0
# 2               4          3.2             3          0.2        0
# 3               3          3.1             5          0.2        0
# 4               7          3.6             4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145            24          3.0            28          2.3        2
# 146            20          2.5            26          1.9        2
# 147            22          3.0            28          2.0        2
# 148            19          3.4            30          2.3        2
# 149            16          3.0            27          1.8        2
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
k=StandardScaler()
data[['species']]=k.fit_transform(data[['species']])
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width   species
# 0               8          3.5             4          0.2 -1.224745
# 1               6          3.0             4          0.2 -1.224745
# 2               4          3.2             3          0.2 -1.224745
# 3               3          3.1             5          0.2 -1.224745
# 4               7          3.6             4          0.2 -1.224745
# ..            ...          ...           ...          ...       ...
# 145            24          3.0            28          2.3  1.224745
# 146            20          2.5            26          1.9  1.224745
# 147            22          3.0            28          2.0  1.224745
# 148            19          3.4            30          2.3  1.224745
# 149            16          3.0            27          1.8  1.224745
#
# [150 rows x 5 columns]

# %%
corelation_matrix=data.corr()
print(corelation_matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   species
# sepal_length      1.000000    -0.121713      0.898023     0.821432  0.785590
# sepal_width      -0.121713     1.000000     -0.311698    -0.366126 -0.426658
# petal_length      0.898023    -0.311698      1.000000     0.947310  0.938952
# petal_width       0.821432    -0.366126      0.947310     1.000000  0.956547
# species           0.785590    -0.426658      0.938952     0.956547  1.000000

# %%
sns.heatmap(corelation_matrix,annot=True)
# Out:
# <Axes: >

# %%
data=sns.load_dataset("penguins")
print(data)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
o=data['bill_length_mm'].mean()
data['bill_length_mm'].fillna(o,inplace=True)

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
r=MinMaxScaler()
data[['bill_length_mm']]=r.fit_transform(data[['bill_length_mm']])
print(data)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen        0.254545           18.7              181.0
# 1    Adelie  Torgersen        0.269091           17.4              186.0
# 2    Adelie  Torgersen        0.298182           18.0              195.0
# 3    Adelie  Torgersen        0.429888            NaN                NaN
# 4    Adelie  Torgersen        0.167273           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe        0.429888            NaN                NaN
# 340  Gentoo     Biscoe        0.534545           14.3              215.0
# 341  Gentoo     Biscoe        0.665455           15.7              222.0
# 342  Gentoo     Biscoe        0.476364           14.8              212.0
# 343  Gentoo     Biscoe        0.647273           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
data.plot()
# Out:
# <Axes: >
